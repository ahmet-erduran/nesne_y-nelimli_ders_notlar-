# %%
print ("Cameron Calero \n2045 Heliport Loop Riverfolk, \nIN 43286 \n812-555-1212")
# Out:
# Cameron Calero
# 2045 Heliport Loop Riverfolk,
# IN 43286
# 812-555-1212

# %%
brut_gelir = int(input("Toplam geliri giriniz = "))
kar_marji = brut_gelir*0.23
print ( kar_marji )
# Out:
# Toplam geliri giriniz =  100
# 23.0

# %%
toplam_mk=int(input("Toplam alanı giriniz = "))
donum_miktarı=toplam_mk/43.560
print (donum_miktarı)
# Out:
# Toplam alanı giriniz =  9687954
# 222404.8209366391

# %%
item1=int(input("Ürünün fiyatını yazınız = "))
toplam=print(item1,item1*0.07)
item2=int(input("Ürünün fiyatını yazınız = "))
toplam=print(item1+item2,item2*0.07)
item3=int(input("Ürünün fiyatını yazınız = "))
toplam=print(item1+item2+item3,item3*0.07)
item4=int(input("Ürünün fiyatını yazınız = "))
toplam=print(item1+item2+item3+item4,item4*0.07)
item5=int(input("Ürünün fiyatını yazınız = "))
toplam=print("Toplam Fatura = ",item1+item2+item3+item4+item5,item5*0.07)
